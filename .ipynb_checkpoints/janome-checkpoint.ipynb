# %%
from bs4 import BeautifulSoup
import requests

res = requests.get("https://shimoda.kanabakariz.com/")
soup = BeautifulSoup(res.text)
ps = soup.find_all("p")  # 全ての<h2>...</h2>を取得
for p in ps:
#     print(p.text)  # .textでテキストを取得
    source = open("source.txt", "a")
    source.write(p.text)
    source.close()

# %%
# -*- coding: utf-8 -*-

import random
from janome.tokenizer import Tokenizer


# Janomeを使用してテキストデータを単語に分割する
def wakati(text):
    text = text.replace('\n', '')  #改行を削除
    text = text.replace('\r', '')  #スペースを削除
    t = Tokenizer()
    result = t.tokenize(text, wakati=True)
    return result


#デフォルトの文の数は5
def generate_text(num_sentence=10):
    filename = "source.txt"
    src = open(filename, "r").read()
    wordlist = wakati(src)

    #マルコフ連鎖用のテーブルを作成
    markov = {}
    w1 = ""
    w2 = ""
    for word in wordlist:
        if w1 and w2:
            if (w1, w2) not in markov:
                markov[(w1, w2)] = []
            markov[(w1, w2)].append(word)
        w1, w2 = w2, word

    #文章の自動生成
    count_kuten = 0  #句点「。」の数
    num_sentence = num_sentence
    sentence = ""
    w1, w2 = random.choice(list(markov.keys()))
    while count_kuten < num_sentence:
        tmp = random.choice(markov[(w1, w2)])
        sentence += tmp
        if (tmp == '。'):
            count_kuten += 1
            sentence += '\n'  #1文ごとに改行
        w1, w2 = w2, tmp

    print(sentence)


if __name__ == "__main__":
    generate_text()
# Out:
# を多く用いて設計をする我々にその可能性が獲得された『現在』としての自己批判的精神を持って他の人の作家の中で、ある程度客観的な解法が示されている。
# シュヴァルはこの家が求められるようになってここまで直裁に再登場することでこの住宅は終わらない」（石山修武）より。
# 　ムトカ建築事務所の「幸福」（石山修武）とシニフィアン（記号表現）の影である。
# 　「宣言」をショーケース越しに見ると、現実と主体の間に言語活動（＝イメージ）のアプローチも異なっている。
# 近づいてみると建築設計手法について、設計活動をするなどである。
# 中野本町の家」（こちらは「名付け」であろう。
# ここで、現在過渡期の住まいに対してカッコをつけ、一時保留し、地面レベルより下に設定し、効果は無生物である。
# リフォームでは世代論や当代の価値観がそこに危機感を与えるとともに、一つの建築家としてバックミンスター・フラーを挙げたい。
# 共感世代の建築の建ち現れ方という単一事象の問題に留まることのできないかと思う。
# 　そもそも資本主義とはそうした現在性が指摘され、以来1300年間遷宮が繰り返されていた。
