# %%
from bs4 import BeautifulSoup
import requests

res = requests.get("https://shimoda.kanabakariz.com/")
soup = BeautifulSoup(res.text)
ps = soup.find_all("p")  # 全ての<h2>...</h2>を取得
for p in ps:
#     print(p.text)  # .textでテキストを取得
    source = open("source.txt", "a")
    source.write(p.text)
    source.close()

# %%
# -*- coding: utf-8 -*-

import random
from janome.tokenizer import Tokenizer


# Janomeを使用してテキストデータを単語に分割する
def wakati(text):
    text = text.replace('\n', '')  #改行を削除
    text = text.replace('\r', '')  #スペースを削除
    t = Tokenizer()
    result = t.tokenize(text, wakati=True)
    return result


#デフォルトの文の数は5
def generate_text(num_sentence=30):
    filename = "source.txt"
    src = open(filename, "r").read()
    wordlist = wakati(src)

    #マルコフ連鎖用のテーブルを作成
    markov = {}
    w1 = ""
    w2 = ""
    for word in wordlist:
        if w1 and w2:
            if (w1, w2) not in markov:
                markov[(w1, w2)] = []
            markov[(w1, w2)].append(word)
        w1, w2 = w2, word

    #文章の自動生成
    count_kuten = 0  #句点「。」の数
    num_sentence = num_sentence
    sentence = ""
    w1, w2 = random.choice(list(markov.keys()))
    while count_kuten < num_sentence:
        tmp = random.choice(markov[(w1, w2)])
        sentence += tmp
        if (tmp == '。'):
            count_kuten += 1
            sentence += '\n'  #1文ごとに改行
        w1, w2 = w2, tmp

    print(sentence)


if __name__ == "__main__":
    generate_text()
# Out:
# であるともほぼ変わらない。
# デザインというのは、施主＝設計者のみならず多くの人や社会全般に対し何らかの現象・変化をもたらせしめようと試みる。
# 　建築家”のような０年代のか弱く自閉的な表現志向というのは「差異」は老朽化し、プロトタイプ化されている「共時性の波が交互に打ち寄せてくる。
# それぞれの象限の面積にバリエーションが生まれ、機能的・構造的・構造的・構造的・構造的・環境的な問題解決がお手本のような各次元の相関世界を夢想することで獲得されていた。
# 　「呪」は、日本の在来工法で流通する105mmの小さな建築家としてバックミンスター・フラーを挙げたい。
# 　 三家大地の「ガムハウス」に分解されるのが恒例となっていることによってはじめて人間は必ず何かに青い空には断熱がないため閉鎖的に俯瞰している。
# ここでスティーブ・ライヒの「北越谷の住宅である。
# 永遠性は、敷地の些細な文脈の中で、受賞コメントにおけるそれとオーバーラップするような趣の井戸が設えられていることができる。
# コトについても在来工法で流通する105mmの小さな建築家では、一個人内での空間が可能かという問題は、建築の建ち現れ方の差異を巡って多様な工夫をこらして利潤を生んでいる。
# 建物は呪いをかける時間の平行な連なりを指している。
# 　このような作品が一つ置かれているが、単純な操作を行なっているダイマキシオン・ハウスに代表されるダイマキシオン・シリーズでは生温いほど差し迫った問題を相対化された「自由」の「我孫子の家」、2018年同2月号は毎年恒例の「House in Los Vilos」そっくりのロケーションと写真のアングルが似てきたように表現するか、という二つの巻頭論文『「レジャー」という状況が、「人口減少社会では開口に沿ってベンチを設けることで、面的時間面積の大きな世界が表現されたものを示唆するのは吉岡賞に関する記事である。
# 　12月号がせっかくの「いいね」の正体がある。
# また先に述べたようにレベルをずらして配された」もので実に雄弁であるからだ。
# ちなみにこれは、不動産を所有していると言えるだろう。
# また先に述べた冨永美保＋伊藤孝仁（tomito architecture）の影であることは驚きであった。
# ...
